# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 12

fig_size[1] = 10

plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# # Checking to see if any NULL values in no. of bedroom or bathroom

# %%
print("number of NaN values for the column bedrooms :", df['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 0
# number of NaN values for the column bathrooms : 0

# %%
df['floors'].value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %% [markdown]
# # Plotting relation b/w Floors and Price of House

# %%
sns.barplot(x='floors', y='price', data=df)

# %% [markdown]
# # Plotting relation b/w Sqft_Above and Price of House

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
plt.title("house prices by sqft_above")
plt.xlabel('sqft_above')
plt.ylabel('house prices')
plt.legend()
sns.barplot(x='sqft_above',y='price',data=df)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Plotting relation b/w Sqft_Basement and Price of House

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
plt.title("house prices by sqft_basement")
plt.xlabel('sqft_basement')
plt.ylabel('house prices')
plt.legend()
sns.barplot(x='sqft_basement',y='price',data=df)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Plotting relation b/w Sqft_Living and Price of House

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
plt.title("house prices by sqft_living")
plt.xlabel('sqft_living')
plt.ylabel('house prices')
plt.legend()
sns.barplot(x='sqft_living',y='price',data=df)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Plotting relation b/w Sqft_Lot and Price of House

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
plt.title("house prices by sqft_lot")
plt.xlabel('sqft_lot')
plt.ylabel('house prices')
plt.legend()
sns.barplot(x='sqft_lot',y='price',data=df)
# Out:
# No handles with labels found to put in legend.

# %%
df['view'].value_counts().to_frame()
# Out:
#     view
# 0  19489
# 2    963
# 3    510
# 1    332
# 4    319

# %% [markdown]
# # Plotting relation b/w View and Price of House

# %%
sns.barplot(x='view', y='price', data=df)

# %%
df['bedrooms'].value_counts().to_frame()
# Out:
#     bedrooms
# 3       9824
# 4       6882
# 2       2760
# 5       1601
# 6        272
# 1        199
# 7         38
# 8         13
# 0         13
# 9          6
# 10         3
# 11         1
# 33         1

# %% [markdown]
# # Plotting relation b/w #Bedrooms and Price of House

# %%
sns.barplot(x='bedrooms', y='price', data=df)

# %%
df['bathrooms'].value_counts().to_frame()
# Out:
#       bathrooms
# 2.50       5380
# 1.00       3852
# 1.75       3048
# 2.25       2047
# 2.00       1930
# 1.50       1446
# 2.75       1185
# 3.00        753
# 3.50        731
# 3.25        589
# 3.75        155
# 4.00        136
# 4.50        100
# 4.25         79
# 0.75         72
# 4.75         23
# 5.00         21
# 5.25         13
# 0.00         10
# 5.50         10
# 1.25          9
# 6.00          6
# 0.50          4
# 5.75          4
# 8.00          2
# 6.25          2
# 6.50          2
# 6.75          2
# 7.50          1
# 7.75          1

# %% [markdown]
# # Plotting relation b/w #Bathrooms and Price of House

# %%
sns.barplot(x='bathrooms', y='price', data=df)

# %%
df['waterfront'].value_counts().to_frame()
# Out:
#    waterfront
# 0       21450
# 1         163

# %% [markdown]
# # Plotting relation b/w Waterfront and Price of House

# %%
sns.barplot(x='waterfront', y='price', data=df)

# %%
df['condition'].value_counts().to_frame()
# Out:
#    condition
# 3      14031
# 4       5679
# 5       1701
# 2        172
# 1         30

# %% [markdown]
# # Plotting relation b/w Condition and Price of House

# %%
sns.barplot(x='condition', y='price', data=df)

# %%
df['grade'].value_counts().to_frame()
# Out:
#     grade
# 7    8981
# 8    6068
# 9    2615
# 6    2038
# 10   1134
# 11    399
# 5     242
# 12     90
# 4      29
# 13     13
# 3       3
# 1       1

# %% [markdown]
# # Plotting relation b/w Grade and Price of House

# %%
sns.barplot(x='grade', y='price', data=df)

# %% [markdown]
# # Plotting relation b/w Sqft_Living15 and Price of House

# %%
sns.lineplot(x="sqft_living15", y="price", data=df)

# %% [markdown]
# # Plotting relation b/w Sqft_Lot15 and Price of House

# %%
sns.lineplot(x="sqft_lot15", y="price", data=df)

# %% [markdown]
# # Finding Correlation of all Features with Price of House

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
dataset_features = df.drop(['price', 'id', 'date', 'long', 'condition', 'yr_built'], axis=1)
dataset_labels = df['price']

# %%
dataset_features.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    grade  sqft_above  sqft_basement  yr_renovated  zipcode      lat  \
# 0      7        1180              0             0    98178  47.5112
# 1      7        2170            400          1991    98125  47.7210
# 2      6         770              0             0    98028  47.7379
# 3      7        1050            910             0    98136  47.5208
# 4      8        1680              0             0    98074  47.6168
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# ...

# %% [markdown]
# # Heatmap for Correaltion

# %%
corr_mat = df.corr().round(2)
sns.heatmap(data=corr_mat, annot=True)

# %% [markdown]
# # Dividing dataset into Test(35%) and Training(65%) data

# %%
from sklearn.model_selection import train_test_split

train_features,test_features,train_labels,test_labels = train_test_split(dataset_features,dataset_labels,test_size=0.35, random_state=2)

# %% [markdown]
# # Implementing Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
rg = LinearRegression()

# %%
rg.fit(train_features, train_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Accuracy of model after Linear Regression

# %%
rg.score(test_features,test_labels)
# Out:
# 0.669956140746919

# %%
predicted_price = rg.predict(test_features)

# %%
plt.scatter(test_labels , predicted_price)

# %%
df1 = pd.DataFrame({'Actual': test_labels, 'Predicted':predicted_price})
df2 = df1.head(10)
df2
# Out:
#           Actual     Predicted
# 6638    735000.0  5.917252e+05
# 7366   1150000.0  1.468806e+06
# 3158    350500.0  4.798465e+05
# 9117    860000.0  1.324412e+06
# 3392    122000.0 -3.597340e+04
# 305     725000.0  5.853321e+05
# 14462   417000.0  6.577553e+05
# 6196    594950.0  6.095119e+05
# 10194   471000.0  5.178146e+05
# 13457   634950.0  6.540606e+05

# %% [markdown]
# # Bar graph plot b/w Actual and Predicted House Prices

# %%
df2.plot(kind = 'bar')

# %%
print(predicted_price)
# Out:
# [ 591725.23506544 1468806.3382455   479846.52610892 ...  295710.70871841
#   269109.14909557  951212.3716601 ]

# %%
predicted_price.shape
# Out:
# (7565,)

# %%
params = {'n_estimators': 400, 'max_depth':5, 'min_samples_split':2, 'learning_rate':0.1, 'loss':'ls'}

# %% [markdown]
# # Implementing Gradient Boosting Regression

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(train_features, train_labels)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=5,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=400,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# # Accuracy of model after Gradient Boosting Regression

# %%
clf.score(test_features,test_labels)
# Out:
# 0.8726610110067479

# %%
predicted_price1 = clf.predict(test_features)

# %%
plt.scatter(test_labels , predicted_price1)

# %%
df3 = pd.DataFrame({'Actual': test_labels, 'Predicted':predicted_price1})
df4 = df3.head(10)
df4
# Out:
#           Actual     Predicted
# 6638    735000.0  6.764212e+05
# 7366   1150000.0  1.259025e+06
# 3158    350500.0  4.870866e+05
# 9117    860000.0  7.700115e+05
# 3392    122000.0  1.645881e+05
# 305     725000.0  6.352161e+05
# 14462   417000.0  3.735819e+05
# 6196    594950.0  6.394942e+05
# 10194   471000.0  4.583020e+05
# 13457   634950.0  6.382482e+05

# %% [markdown]
# # Bar graph plot b/w Actual and Predicted House Prices

# %%
df4.plot(kind = 'bar')
